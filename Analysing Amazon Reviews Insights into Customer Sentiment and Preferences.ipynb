# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("D://M.sc IT//MSC-IT-4 YEAR//SEM-8//Data Science//FDS//train.csv")

# %%
df
# Out:
#              No  polarity                                              Title  \
# 0             1         2                     Stuning even for the non-gamer
# 1             2         2              The best soundtrack ever to anything.
# 2             3         2                                           Amazing!
# 3             4         2                               Excellent Soundtrack
# 4             5         2  Remember, Pull Your Jaw Off The Floor After He...
# ...         ...       ...                                                ...
# 999995   999996         2                            Not as good as expected
# 999996   999997         2                                       Quality lens
# 999997   999998         2                            Haven't used it enough.
# 999998   999999         2                           Canon L Lens at its Best
# 999999  1000000         2                                         Great lens
#
# ...

# %%
df.head()
# Out:
#    No  polarity                                              Title  \
# 0   1         2                     Stuning even for the non-gamer
# 1   2         2              The best soundtrack ever to anything.
# 2   3         2                                           Amazing!
# 3   4         2                               Excellent Soundtrack
# 4   5         2  Remember, Pull Your Jaw Off The Floor After He...
#
#                                      Review_Detailes
# 0  This sound track was beautiful! It paints the ...
# 1  I'm reading a lot of reviews saying that this ...
# 2  This soundtrack is my favorite music of all ti...
# 3  I truly like this soundtrack and I enjoy video...
# 4  If you've played the game, you know how divine...

# %%
df.tail()
# Out:
#              No  polarity                     Title  \
# 999995   999996         2   Not as good as expected
# 999996   999997         2              Quality lens
# 999997   999998         2   Haven't used it enough.
# 999998   999999         2  Canon L Lens at its Best
# 999999  1000000         2                Great lens
#
#                                           Review_Detailes
# 999995  First off, let me say this is a great lens. It...
# 999996  Very good quality lens, feels solid and the pi...
# 999997  Haven't used it enough to make an informed dec...
# 999998  Got this lens with my Canon 5D Mark II and it ...
# 999999  I've had this lens for 2 months now, and love ...

# %%
#no of rows
rows =len(df.axes[0])
print("Rows :",rows)

#no of columns
cols =len(df.axes[1])
print("Columns :",cols)

df.shape
# Out:
# Rows : 1000000
# Columns : 4
# (1000000, 4)

# %%
df.describe().transpose()
# Out:
#               count           mean            std  min        25%       50%  \
# No        1000000.0  500000.500000  288675.278933  1.0  250000.75  500000.5
# polarity  1000000.0       1.505678       0.499968  1.0       1.00       2.0
#
#                 75%        max
# No        750000.25  1000000.0
# polarity       2.00        2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   No               1000000 non-null  int64
#  1   polarity         1000000 non-null  int64
#  2   Title            999973 non-null   object
#  3   Review_Detailes  1000000 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 30.5+ MB

# %%
df.dtypes
# Out:
# No                  int64
# polarity            int64
# Title              object
# Review_Detailes    object
# dtype: object

# %%
categorical_columns = df.select_dtypes(include=["object"]).columns
print(categorical_columns)
# Out:
# Index(['Title', 'Review_Detailes'], dtype='object')

# %%
quantitative = df.select_dtypes(include=["int64","float64"]).keys()
print(quantitative)
# Out:
# Index(['No', 'polarity'], dtype='object')

# %%
#histogram
polarity_columns = [col for col in df.columns if 'polarity' in col]
plt.rcParams['figure.figsize'] = 6, 8
df[polarity_columns].hist()
plt.show()

# %%
# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# No                  0
# polarity            0
# Title              27
# Review_Detailes     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("First few rows of the DataFrame:")
print(df.head())

# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())

# Summary statistics
print("\nSummary statistics:")
print(df.describe())

# Rename columns to remove whitespace characters
df.columns = df.columns.str.strip()

# Distribution of Polarity
plt.figure(figsize=(8, 6))
sns.countplot(x='polarity', data=df)
plt.title('Distribution of Polarity')
plt.xlabel('Polarity')
plt.ylabel('Count')
plt.show()
# Out:
# First few rows of the DataFrame:
#    No  polarity                                              Title  \
# 0   1         2                     Stuning even for the non-gamer
# 1   2         2              The best soundtrack ever to anything.
# 2   3         2                                           Amazing!
# 3   4         2                               Excellent Soundtrack
# 4   5         2  Remember, Pull Your Jaw Off The Floor After He...
#
#                                      Review_Detailes
# 0  This sound track was beautiful! It paints the ...
# 1  I'm reading a lot of reviews saying that this ...
# 2  This soundtrack is my favorite music of all ti...
# 3  I truly like this soundtrack and I enjoy video...
# 4  If you've played the game, you know how divine...
#
# Missing values:
# No                  0
# polarity            0
# Title              27
# Review_Detailes     0
# dtype: int64
#
# Summary statistics:
#                    No        polarity
# ...

# %%
# Word count distribution of Review Detail
df['Word Count'] = df['Review_Detailes'].apply(lambda x: len(x.split()))
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Word Count', bins=30, kde=True)
plt.title('Distribution of Word Count in Reviews')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()

# %%
# Analysis of Review Title length
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assume df is your DataFrame and has been loaded correctly
# Fill NaN values in the 'Title' column with an empty string
df['Title'] = df['Title'].fillna('')

# Calculate the length of each review title
df['Title_Length'] = df['Title'].apply(lambda x: len(x.split()))

# Plot the distribution of review title length by polarity
plt.figure(figsize=(10, 6))
sns.boxplot(x='polarity', y='Title_Length', data=df)
plt.title('Distribution of Review Title Length by Polarity')
plt.xlabel('Polarity')
plt.ylabel('Title Length')
plt.show()

# %%
# Word count distribution by Polarity
df['Word Count'] = df['Review_Detailes'].apply(lambda x: len(x.split()))

# Plot the word count distribution by polarity
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Word Count', bins=30, kde=True, hue='polarity')
plt.title('Word Count Distribution by Polarity')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.legend(title='Polarity')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['Title_Length'] = df['Title'].apply(len)

# Plot the length of review titles by polarity
plt.figure(figsize=(10, 6))
sns.boxplot(x='polarity', y='Title_Length', data=df)
plt.title('Length of Review Title by Polarity')
plt.xlabel('Polarity')
plt.ylabel('Title Length')
plt.show()

# %%
# Frequency of Review Titles
plt.figure(figsize=(12, 8))
sns.countplot(y='Title', data=df, order=df['Title'].value_counts().index[:10])
plt.title('Top 10 Most Frequent Review Titles')
plt.xlabel('Frequency')
plt.ylabel('Review Title')
plt.show()

# %%
# Convert text data to numerical features
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Train a logistic regression model
model = LogisticRegression()
model.fit(X_train_vec, y_train)

# Predict on the test set
y_pred = model.predict(X_test_vec)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Review_Details'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud



# Generate word cloud
text = ' '.join(df['Review_Detailes'].astype(str))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.title('Word Cloud of Review Details')
plt.axis('off')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
    
# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Load dataset
df = pd.read_csv("D:\\M.sc IT\\MSC-IT-4 YEAR\\SEM-8\\Data Science\\FDS\\sample_dataset_amazonreview.csv") 


tokenized_texts = []
for text in df['Review_Detailes']:  
    tokens = word_tokenize(text)
    # Lowercasing
    tokens = [word.lower() for word in tokens]
    tokenized_texts.append(tokens)

# Now tokenized_texts contains tokenized and lowercased text for each row in your dataset
print(tokenized_texts)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\darsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\darsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
# Remove punctuation
translator = str.maketrans('', '', string.punctuation)
df['Review_Detailes'] = df['Review_Detailes'].apply(lambda x: x.translate(translator))

# Tokenize and remove stopwords
stop_words = set(stopwords.words('english'))
df['Tokenized_Text'] = df['Review_Detailes'].apply(lambda x: [word for word in word_tokenize(x.lower()) if word.isalnum() and word not in stop_words])

# Print tokens
print(df['Tokenized_Text'])
# Out:
# 0      [sound, track, beautiful, paints, senery, mind...
# 1      [im, reading, lot, reviews, saying, best, game...
# 2      [soundtrack, favorite, music, time, hands, int...
# 3      [truly, like, soundtrack, enjoy, video, game, ...
# 4      [youve, played, game, know, divine, music, eve...
#                              ...
# 495    [book, wonderful, illustration, simple, simple...
# 496    [think, beyond, fact, hazlitt, produces, succi...
# 497    [economics, one, lesson, elucidates, basic, pr...
# 498    [economics, one, lesson, another, great, must,...
# 499    [sure, specific, examples, cited, 60, years, a...
# Name: Tokenized_Text, Length: 500, dtype: object

# %%
df['Tokenized_Text'] = df['Tokenized_Text'].apply(lambda x: ' '.join(x))

# %%
#Bagging Accuracy: 0.75
#Boosting Accuracy: 0.69 with pre-processing

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Load dataset
df = pd.read_csv("D:\\M.sc IT\\MSC-IT-4 YEAR\\SEM-8\\Data Science\\FDS\\sample_dataset_amazonreview.csv") 

# Step 2: Preprocess the data

# Remove punctuation
translator = str.maketrans('', '', string.punctuation)
df['Review_Detailes'] = df['Review_Detailes'].apply(lambda x: x.translate(translator))

# Tokenize and remove stopwords
stop_words = set(stopwords.words('english'))
df['Tokenized_Text'] = df['Review_Detailes'].apply(lambda x: [word for word in word_tokenize(x.lower()) if word.isalnum() and word not in stop_words])

# Print tokens
print(df['Tokenized_Text'])

# Join tokens to form the final processed text
df['Processed_Text'] = df['Tokenized_Text'].apply(lambda x: ' '.join(x))

# Step 3: Split the dataset into features and target variable
X = df['Processed_Text']
y = df['polarity']

# Step 4: Vectorize the text data
vectorizer = TfidfVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# Step 5: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

# Step 6: Define a base model
base_model = DecisionTreeClassifier()

# Step 7: Implement bagging and boosting
bagging_classifier = BaggingClassifier(base_model, n_estimators=50, random_state=42)
boosting_classifier = AdaBoostClassifier(base_model, n_estimators=50, random_state=42)

# Step 8: Train and evaluate the models
bagging_classifier.fit(X_train, y_train)
boosting_classifier.fit(X_train, y_train)

bagging_pred = bagging_classifier.predict(X_test)
boosting_pred = boosting_classifier.predict(X_test)

bagging_accuracy = accuracy_score(y_test, bagging_pred)
boosting_accuracy = accuracy_score(y_test, boosting_pred)

print("Bagging Accuracy:", bagging_accuracy)
print("Boosting Accuracy:", boosting_accuracy)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\darsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\darsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0      [sound, track, beautiful, paints, senery, mind...
# 1      [im, reading, lot, reviews, saying, best, game...
# 2      [soundtrack, favorite, music, time, hands, int...
# 3      [truly, like, soundtrack, enjoy, video, game, ...
# 4      [youve, played, game, know, divine, music, eve...
#                              ...
# 495    [book, wonderful, illustration, simple, simple...
# 496    [think, beyond, fact, hazlitt, produces, succi...
# 497    [economics, one, lesson, elucidates, basic, pr...
# 498    [economics, one, lesson, another, great, must,...
# 499    [sure, specific, examples, cited, 60, years, a...
# Name: Tokenized_Text, Length: 500, dtype: object
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import LSTM, Embedding, Dense, SpatialDropout1D
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Step 1: Read the dataset
df = pd.read_csv("D:\\M.sc IT\\MSC-IT-4 YEAR\\SEM-8\\Data Science\\FDS\\sample_dataset_amazonreview.csv")



# Step 2: Split the dataset into features and target variable
X = df['Review_Detailes']
y = df['polarity']

# Step 3: Encode the target variable
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)
y = to_categorical(y)

# Step 4: Tokenize the text data
max_words = 1000
tokenizer = Tokenizer(num_words=max_words, split=' ')
tokenizer.fit_on_texts(X)
X_tokenized = tokenizer.texts_to_sequences(X)

# Step 5: Pad sequences
max_len = 100  # Adjust as needed
X_padded = pad_sequences(X_tokenized, maxlen=max_len)

# Step 6: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)

# Step 7: Define the LSTM model architecture
embedding_size = 128
lstm_units = 64

model = Sequential()
model.add(Embedding(max_words, embedding_size, input_length=max_len))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(lstm_units, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(2, activation='softmax'))  # Assuming 2 classes for polarity

# Step 9: Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Step 10: Train the model
batch_size = 32
epochs = 5
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

# Step 11: Evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1] * 100))



history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\darsh\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\darsh\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\darsh\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\darsh\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import LSTM, Embedding, Dense, SpatialDropout1D
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Step 1: Read the dataset
df = pd.read_csv("D:\\M.sc IT\\MSC-IT-4 YEAR\\SEM-8\\Data Science\\FDS\\sample_dataset_amazonreview.csv")

# Step 2: Preprocess the data

# Remove punctuation
translator = str.maketrans('', '', string.punctuation)
df['Review_Detailes'] = df['Review_Detailes'].apply(lambda x: x.translate(translator))

# Tokenize and remove stopwords
stop_words = set(stopwords.words('english'))
df['Processed_Text'] = df['Review_Detailes'].apply(lambda x: ' '.join([word for word in word_tokenize(x.lower()) if word.isalnum() and word not in stop_words]))

# Step 3: Split the dataset into features and target variable
X = df['Processed_Text']
y = df['polarity']

# Step 4: Encode the target variable
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)
y = to_categorical(y)

# Step 5: Tokenize the text data
max_words = 1000
tokenizer = Tokenizer(num_words=max_words, split=' ')
tokenizer.fit_on_texts(X)
X_tokenized = tokenizer.texts_to_sequences(X)

# Step 6: Pad sequences
max_len = 100  # Adjust as needed
X_padded = pad_sequences(X_tokenized, maxlen=max_len)

# Step 7: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)

# Step 8: Define the LSTM model architecture
embedding_size = 128
lstm_units = 64

model = Sequential()
model.add(Embedding(max_words, embedding_size, input_length=max_len))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(lstm_units, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(2, activation='softmax'))  # Assuming 2 classes for polarity

# Step 9: Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Step 10: Train the model
epochs = 5  # Adjust as needed
batch_size = 32  # Adjust as needed
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

# Step 11: Evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1] * 100))

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\darsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\darsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Epoch 1/5
# 13/13 [==============================] - 4s 87ms/step - loss: 0.6904 - accuracy: 0.5425 - val_loss: 0.6854 - val_accuracy: 0.6500
# Epoch 2/5
# 13/13 [==============================] - 1s 65ms/step - loss: 0.6642 - accuracy: 0.7200 - val_loss: 0.6558 - val_accuracy: 0.6900
# Epoch 3/5
# 13/13 [==============================] - 1s 65ms/step - loss: 0.5694 - accuracy: 0.8200 - val_loss: 0.5552 - val_accuracy: 0.7300
# Epoch 4/5
# 13/13 [==============================] - 1s 64ms/step - loss: 0.3446 - accuracy: 0.8825 - val_loss: 0.5959 - val_accuracy: 0.7400
# Epoch 5/5
# ...

# %%
#sentiment analysis

import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob

# Read the dataset into a pandas DataFrame
df = pd.read_csv("D:\\M.sc IT\\MSC-IT-4 YEAR\\SEM-8\\Data Science\\FDS\\sample_dataset_amazonreview.csv")

# Preprocessing
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    words = word_tokenize(str(text).lower())
    words = [word for word in words if word.isalnum() and word not in stop_words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

df['Processed_Text'] = df['Review_Detailes'].apply(preprocess_text)

# Sentiment analysis using TextBlob
def analyze_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

df['sentiment'] = df['Processed_Text'].apply(analyze_sentiment)

# Plot sentiment distribution
plt.figure(figsize=(8, 6))
df['sentiment'].plot(kind='hist', bins=50, color="skyblue", edgecolor="black")
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Frequency')
plt.show()
